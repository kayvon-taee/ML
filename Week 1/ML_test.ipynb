# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
airpoll_data =  pd.read_csv("airpoll.csv", index_col="City").head()

# %%
# Get a list of features to plot
features = airpoll_data.drop(labels="Mortality", axis=1).columns.tolist()
y_values = airpoll_data["Mortality"]

fig, axes = plt.subplots(nrows=len(features), ncols=2, figsize=(8,4 * len(features)))

for element in enumerate(features):
    print(element)
# Out:
# (0, 'Rainfall')
# (1, 'Education')
# (2, 'Popden')
# (3, 'Nonwhite')
# (4, 'NOX')
# (5, 'SO2')
